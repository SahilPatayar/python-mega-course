# %%
import pandas
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'learn_pandas.ipynb',
#  'README.md',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
df_csv = pandas.read_csv("supermarkets.csv")
df_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_json = pandas.read_json("supermarkets.json")
df_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_txt_comma = pandas.read_csv("supermarkets-commas.txt")
df_txt_comma
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_txt_semi = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df_txt_semi
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_xls = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df_xls
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df_csv = pandas.read_csv("supermarkets.csv")
df_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_csv.iloc[0 : 3, 2 : 5]
# Out:
#             City             State Country
# 0  San Francisco          CA 94114     USA
# 1  San Francisco          CA 94119     USA
# 2  San Francisco  California 94114     USA

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1.index
df1.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df1.drop(df1.index[0:3], axis=0)
# Out:
#    ID          Address           City       State Country        Name  \
# 3   4     3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop
# 4   5  1056 Sanchez St  San Francisco  California     USA     Sanchez
# 5   6  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley
#
#    Employees
# 3         10
# 4         12
# 5         20

# %%
df1.shape
# Out:
# (6, 7)

# %%
df1["continent"] = "North America"

# %%
superMarketData = pandas.read_csv("supermarkets.csv")
superMarketData
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
superMarketData["Full_Address"] = superMarketData["Address"] + " , " + superMarketData["City"] +  " , " + superMarketData["State"] + " , " + superMarketData["Country"]

# %%
superMarketData
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                       Full_Address
# 0          8      3666 21st St , San Francisco , CA 94114 , USA
# 1         15    735 Dolores St , San Francisco , CA 94119 , USA
# 2         25  332 Hill St , San Francisco , California 94114...
# 3         10      3995 23rd St , San Francisco , CA 94114 , USA
# 4         12  1056 Sanchez St , San Francisco , California ,...
# 5         20   551 Alvarado St , San Francisco , CA 94114 , USA

# %%
from geopy.geocoders import ArcGIS
import pandas

geoService = ArcGIS()

addrLocation = geoService.geocode("3666 21st St, San Francisco, CA 94114, USA")

print("Latitude: " + str(addrLocation.latitude))
print("Longitude: " + str(addrLocation.longitude))

######
superMarketData = pandas.read_csv("supermarkets.csv")
#City,State,Country
superMarketData["Full_Address"] = superMarketData["Address"] + " , " + superMarketData["City"] +  " , " + superMarketData["State"] + " , " + superMarketData["Country"]

superMarketData["Location"] = superMarketData["Full_Address"].apply(geoService.geocode)

superMarketData["Latitude"] = superMarketData["Location"].apply(lambda loc : loc.latitude if loc is not None else None)

superMarketData["Longitude"] = superMarketData["Location"].apply(lambda loc : loc.longitude if loc is not None else None)
# Out:
# Latitude: 37.756648011392286
# Longitude: -122.42937496976432

# %%
superMarketData.drop("Full_Address", axis=1, inplace=True)

# %%
superMarketData
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                           Location   Latitude  \
# 0          8  (3666 21st St, San Francisco, California, 9411...  37.756648
# 1         15  (735 Dolores St, San Francisco, California, 94...  37.757819
# 2         25  (332 Hill St, San Francisco, California, 94114...  37.755875
# 3         10  (3995 23rd St, San Francisco, California, 9411...  37.752922
# 4         12  (1056 Sanchez St, San Francisco, California, 9...  37.752131
# 5         20  (551 Alvarado St, San Francisco, California, 9...  37.753511
#
#     Longitude
# 0 -122.429375
# 1 -122.425337
# 2 -122.428816
# 3 -122.431697
# 4 -122.430028
# 5 -122.433229
